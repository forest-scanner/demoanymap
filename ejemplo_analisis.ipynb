# %% [markdown]
# # Análisis del Parque Norte de Madrid - Notebook de Ejemplo
#
# Este notebook muestra el uso de las funciones principales del proyecto.

# %%
# Importar la clase principal
from parque_norte_madrid import ParqueNorteMadrid

# Crear instancia
parque = ParqueNorteMadrid()
print(f"Análisis de: {parque.nombre}")
print(f"Coordenadas: {parque.coordenadas}")

# %%
# Generar datos
datos = parque.generar_datos_simulados(dias=180)
print(f"Datos generados: {len(datos)} registros")
datos.head()

# %%
# Estadísticas básicas
print("Estadísticas de visitantes:")
print(datos['visitantes'].describe())

print("\nEstadísticas de temperatura:")
print(datos['temperatura'].describe())

# %%
# Crear visualizaciones
import matplotlib.pyplot as plt

fig = parque.generar_visualizaciones()
plt.show()

# %%
# Mostrar mapa interactivo (en notebook)
mapa = parque.crear_mapa_interactivo()
mapa

# %%
# Análisis de series temporales
analisis_mensual = parque.analizar_series_temporales()
print("Análisis mensual:")
analisis_mensual.tail()

# %% [markdown]
# ## Conclusiones
#
# Este análisis muestra:
# 1. Patrones estacionales en la visita al parque
# 2. Relación entre temperatura y visitantes
# 3. Distribución de actividades preferidas
# 4. Variación por días de la semana
